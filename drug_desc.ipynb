# %%
import json
from bs4 import BeautifulSoup

# %%
with open("d:/ticket/processed/no_desc_drug.json", "r") as f:
    ndd_dict = json.load(f)

# %%
for key, value in ndd_dict.items():
    if value == "no data":
        continue

    soup = BeautifulSoup(value, 'html.parser')
# Out:
# {'十一味金色丸': '\n        <thead>\n          <tr>\n                          <th data-priority="" width="">\n                                药品名称              </th>              <th data-priority="1" width="">\n                                说明书来源              </th>              <th data-priority="1" width="">\n                                <a href="/index.php/Instruct/index?dbname=instruct&amp;name=%E5%8D%81%E4%B8%80%E5%91%B3%E9%87%91%E8%89%B2%E4%B8%B8&amp;list_order=">最新修订日期                        <i class="fa cl-red">\uf0de</i>\n                      </a>\n                              </th>              <th data-priority="1" width="">\n                                包装图片              </th>              <th data-priority="" width="">\n                                查看全文              </th>          </tr>\n        </thead>\n        <tbody>\n\n          <tr>\n                                                                                  <td>十一味金色丸</td>                            
# ...

# %%
with open("processed/cmekg_disease_drug_list.json", "r") as f:
    cdd_dict = json.load(f)

# %%
cdd_dict
# Out:
# [['过敏性紫癜性肾炎', '环磷酰胺'],
#  ['过敏性紫癜性肾炎', '泼尼松'],
#  ['过敏性紫癜性肾炎', '硫唑嘌呤'],
#  ['心肌梗塞', '低分子肝素'],
#  ['心肌梗塞', '氯吡格雷'],
#  ['心肌梗塞', '吗啡'],
#  ['心肌梗塞', '硝酸甘油'],
#  ['心肌梗塞', '硝苯地平'],
#  ['心肌梗塞', '地尔硫'],
#  ['心肌梗塞', '维拉帕米'],
#  ['心肌梗塞', '阿司匹林'],
#  ['腰痛', '羟考酮'],
#  ['慢性皮肤黏膜念珠菌病', '两性霉素b'],
#  ['口腔黏膜炎', '布洛芬'],
#  ['口腔黏膜炎', '曲马多'],
#  ['口腔黏膜炎', '芬太尼'],
#  ['口腔黏膜炎', '羟考酮'],
#  ['口腔黏膜炎', '硫酸吗啡'],
#  ['口腔黏膜炎', '吗啡'],
#  ['口腔黏膜炎', '利多卡因'],
#  ['口腔黏膜炎', '对乙酰氨基酚'],
#  ['口腔黏膜炎', '氟尿嘧啶'],
#  ['链球菌咽炎', '阿莫西林'],
#  ['腹主动脉瘤', '肥厚性心肌病'],
#  ['腹主动脉瘤', '多西环素'],
#  ['腹主动脉瘤', '普萘洛尔'],
#  ['腹主动脉瘤', '罗红霉素'],
#  ['胱氨酸尿症', '青霉胺'],
#  ['胱氨酸尿症', '碳酸氢钠'],
#  ['胱氨酸尿症', '枸橼酸钠'],
#  ['支气管肺癌', '培美曲塞'],
#  ['支气管肺癌', '多西紫杉醇'],
#  ['支气管肺癌', '血管内皮抑素'],
#  ['念珠菌性脑膜炎', '氟康唑'],
#  ['念珠菌性脑膜炎', '伏立康唑'],
#  ['念珠菌性脑膜炎', '两性霉素b'],
#  ['念珠菌性脑膜炎', '氟胞嘧啶'],
#  ['外部性脑积水', '甘露醇'],
#  ['外部性脑积水', '乙酰唑胺'],
#  ['心脏疾病', '阿司匹林'],
#  ['心脏疾病', '拉贝洛尔'],
#  ['噬血细胞性淋巴组织细胞增生症', '氟达拉滨'],
#  ['噬血细胞性淋巴组织细胞增生症', '地塞米松'],
# ...

# %%
    with open("processed/current_disease_icd_dict.json", "r") as f:
        cdi_dict = json.load(f)

# %%
cdi_dict
# Out:
# {'A-V综合征': {'H50.8': '其他特指的斜视'},
#  'Hughes-Stovin综合征': {'I77.6': '未特指的动脉炎'},
#  'Marie-Bamberger综合征': {'M89.4': '其他的肥厚性骨关节病', 'M19.9': '关节病'},
#  'Milk-Alkali综合征': {'E83.5': '钙代谢紊乱'},
#  'Pasini-Pierni进行性皮肤萎缩': {'L90.3': '特发性皮肤萎缩'},
#  'Reis-Bucklers角膜营养不良': {'H18.5': '遗传性角膜营养不良'},
#  'X综合征': {'I20.8': '其他类型的心绞痛', 'Q97.1': '女性,伴多于三个X染色体的', 'E88.8': '其他特指的代谢紊乱'},
#  'α1-抗胰蛋白酶缺乏症': {'E88.0': '血浆蛋白代谢紊乱,不可归类在他处者', 'J98.8': '其他特指的呼吸性疾患'},
#  '一度房室传导阻滞': {'I44.0': '一度房室传导阻滞', 'I44.1': '二度房室传导阻滞', 'I44.2': '完全性房室传导阻滞'},
#  '上肢深静脉血栓形成': {'I80.2': '下肢其他深部脉管的静脉炎和血栓性静脉炎'},
#  '上腔静脉综合征': {'J98.8': '其他特指的呼吸性疾患', 'I87.1': '静脉受压'},
#  '丙酮酸激酶缺乏症': {'E88.8': '其他特指的代谢紊乱', 'D55.8': '其他酶代谢紊乱性贫血'},
#  '严重联合免疫缺陷病': {'D81.9': '未特指的联合免疫缺陷'},
#  '乙型病毒性肝炎': {'B16.9': '急性乙型肝炎,不伴有δ因子(共同感染),也不伴有肝昏迷'},
#  '乳头状腺瘤': {'D24': '乳房良性肿瘤'},
#  '乳溢-闭经综合征': {'E23.6': '其他垂体疾患', 'O92.6': '乳溢', 'E34.8': '其他特指的内分泌疾患'},
#  '乳腺脂肪瘤': {'D17.9': '未特指的良性脂肪瘤样肿瘤', 'D31.6': '未特指的眶良性肿瘤'},
#  '乳酸性酸中毒': {'E87.2': '酸中毒'},
# ...
